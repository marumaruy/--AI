# %%
import matplotlib.pyplot as plt 
import cv2

##カスケードファイルを指定##
cascade_file = "haarcascade_frontalface_alt.xml"
cascade = cv2.CascadeClassifier(cascade_file)

##画像の読み込み##
img = cv2.imread("Angelina-Danilova.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

##顔認識の実行##
face_list = cascade.detectMultiScale(img_gray,minSize = (int(input()),int(input())) )

##結果の確認##
if len(face_list) == 0:
    print("ざ~んね~んでした~♡")
    quit()

##認識部分に印を付与##
for (x,y,w,h) in face_list:
    print("顔の座標:",x,y,w,h)
    red = (0,0,255)
    cv2.rectangle(img ,( x , y) ,(x+w , y + h) , red , thickness = 20  )
    
##画像の出力##
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 150
# 150
# 顔の座標: 272 94 368 368

# %%
import matplotlib.pyplot as plt 
import cv2

##カスケードファイルを指定##
cascade_file = "lbpcascade_animeface.xml"
cascade = cv2.CascadeClassifier(cascade_file)

##画像の読み込み##
img = cv2.imread("emosuke.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

##顔認識の実行##
face_list = cascade.detectMultiScale(img_gray,minSize = (int(input()),int(input())) )

##結果の確認##
if len(face_list) == 0:
    print("残念")
    quit()

##認識部分に印を付与##
for (x,y,w,h) in face_list:
    print("顔の座標:",x,y,w,h)
    red = (0,0,255)
    cv2.rectangle(img ,( x , y) ,(x+w , y + h) , red , thickness = 20  )
    
##画像の出力##
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 100
# 100
# 顔の座標: 285 64 226 226

# %%
import matplotlib.pyplot as plt 
import cv2

##カスケードファイルを指定##
cascade_file = "lbpcascade_animeface.xml"
cascade = cv2.CascadeClassifier(cascade_file)

##画像の読み込み##
img = cv2.imread("miko.jpg")
img_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

##顔認識の実行##
face_list = cascade.detectMultiScale(img_gray,minSize = (int(input()),int(input())) )

##結果の確認##
if len(face_list) == 0:
    print("ざ~んね~んでした~♡")
    quit()

##認識部分に印を付与##
for (x,y,w,h) in face_list:
    print("顔の座標:",x,y,w,h)
    red = (0,0,255)
    cv2.rectangle(img ,( x , y) ,(x+w , y + h) , pink , thickness = 20  )
    
##画像の出力##
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# 150
# 150
# ざ~んね~んでした~♡
